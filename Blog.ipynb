# %% [markdown]
# ### Devanandhan Sp
# ### AM.EN.U4CSE21120

# %%
import pandas as pd 
import numpy as np
import random
import matplotlib.pyplot as plt
from math import pi
import seaborn as sns

# %%
random.seed(42)

# %%
#Defining the regions           
regions=["North Kerala","South Kerala","Central Kerala","Coastal Kerala","Hill Kerala"]

# %%
data={
"Region": regions,
    "Quantum Governance Index": [round(random.uniform(80, 90), 1) for _ in regions],
    "AI-Enhanced Policy Effectiveness": [round(random.uniform(85, 95), 1) for _ in regions],
    "Virtual Town Hall Participation": [f"{random.randint(70, 90)}%" for _ in regions],
    "Neural Public Sentiment Analysis": [f"{random.randint(80, 95)}%" for _ in regions]
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#            Region  Quantum Governance Index  AI-Enhanced Policy Effectiveness  \
# 0    North Kerala                      86.4                              91.8
# 1    South Kerala                      80.3                              93.9
# 2  Central Kerala                      82.8                              85.9
# 3  Coastal Kerala                      82.2                              89.2
# 4     Hill Kerala                      87.4                              85.3
#
#   Virtual Town Hall Participation Neural Public Sentiment Analysis
# 0                             76%                              86%
# 1                             77%                              93%
# 2                             86%                              87%
# 3                             89%                              94%
# 4                             70%                              88%

# %% [markdown]
# # <b>Visualization</b>

# %%
#Visualization
plt.style.use('ggplot')
plt.figure(figsize=(10,6))
plt.bar(df['Region'],df['Quantum Governance Index'],color="c",alpha=0.7)
plt.title('Quantum Governance Index by Region')
plt.xlabel('Region')
plt.ylabel('Quantum Governance Index')
plt.ylim(0,100)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Region'], df['AI-Enhanced Policy Effectiveness'], color='m', alpha=0.7)
plt.title('AI-Enhanced Policy Effectiveness by Region')
plt.xlabel('Region')
plt.ylabel('AI-Enhanced Policy Effectiveness')
plt.ylim(0, 100)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Region'], df['Virtual Town Hall Participation'].str.rstrip('%').astype('float'), color='y', alpha=0.7)
plt.title('Virtual Town Hall Participation by Region')
plt.xlabel('Region')
plt.ylabel('Virtual Town Hall Participation (%)')
plt.ylim(0, 100)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Region'], df['Neural Public Sentiment Analysis'].str.rstrip('%').astype('float'), color='g', alpha=0.7)
plt.title('Neural Public Sentiment Analysis by Region')
plt.xlabel('Region')
plt.ylabel('Neural Public Sentiment Analysis (%)')
plt.ylim(0, 100)
plt.show()

# %%
def plot_radar_chart(data, categories, title):
    plt.figure(figsize=(8, 8))
    
    # Number of variables
    num_vars = len(categories)
    
    # Compute angle of each axis
    angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
    angles += angles[:1]
    
    # Initialize the radar plot
    ax = plt.subplot(111, polar=True)
    
    # Draw one axe per variable + add labels
    plt.xticks(angles[:-1], categories, color='grey', size=10)
    
    # Plot data
    for i, region in enumerate(data['Region']):
        values = data.iloc[i, 1:].tolist()
        values += values[:1]
        ax.plot(angles, values, linewidth=2, linestyle='solid', label=region)
        ax.fill(angles, values, alpha=0.4)
    
    # Add a title
    plt.title(title, size=14, color='black', y=1.1)
    
    # Add a legend
    plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# Select relevant columns for the radar chart
radar_data = df[['Region', 'Quantum Governance Index', 'AI-Enhanced Policy Effectiveness', 'Virtual Town Hall Participation', 'Neural Public Sentiment Analysis']]

# Plot the radar chart
plot_radar_chart(radar_data, categories=['Quantum Governance', 'AI Policy Effectiveness', 'Virtual Town Hall', 'Neural Sentiment'], title='Political Decision-Making Metrics by Region')
plt.show()

# %%
pairplot_data = df[['Quantum Governance Index', 'AI-Enhanced Policy Effectiveness', 'Virtual Town Hall Participation', 'Neural Public Sentiment Analysis']]

# Calculate the correlation matrix
correlation_matrix = pairplot_data.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=.5)
plt.title('Correlation Heatmap of Political Decision-Making Metrics')
plt.show()
# Out:
# /tmp/ipykernel_206010/1264260906.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = pairplot_data.corr()

# %% [markdown]
# #### <u>Blog

# %% [markdown]
# ## <b>Quantum-Backed Political Decision-Making in Kerala: Shaping a Technological Democracy </b>
#
# ### <b>Introduction:</b>
#
# In the hallowed corridors of Kerala's political arena, a groundbreaking shift is on the horizon — the integration of quantum technologies in political decision-making. As we catapult into 2023, envision a Kerala where governance is not just a process but a symphony of quantum-backed strategies, artificial intelligence, and citizen engagement. This blog unfurls the tapestry of this visionary concept, exploring its potential impact on the political landscape of Kerala.
#
# ###  <b>2. Variables and Data:</b>
#
# #### <b>Quantum Governance Index:</b>
# Imagine a governance index infused with the power of quantum technologies. Scores ranging from 0 to 100 unveil the effectiveness of this revolutionary approach, where traditional boundaries between policy and innovation blur.
#
# #### <b>AI-Enhanced Policy Effectiveness: </b>
# In this quantum-infused future, policies aren't just formulated; they're crafted with the precision of artificial intelligence. A metric ranging from 0 to 100 quantifies the efficacy of policies sculpted by algorithms, anticipating the needs and aspirations of the people.
#
# #### <b>Virtual Town Hall Participation:</b>
# The heartbeat of this technological democracy echoes in the Virtual Town Halls, where citizens actively shape political discourse. Participation percentages become a metric for the vibrancy of democratic engagement, setting the stage for a political revolution.
#
# #### <b>Neural Public Sentiment Analysis:</b>
# Quantifying public sentiment through neural networks adds a new dimension to political decision-making. As we assign percentages to the mood of the public, we unearth a treasure trove of insights into the emotional landscape of the electorate.
#
# ### <b> Visualizations: </b>
#
# #### <b>3D Radar Chart:</b>
# ![image-2.png](attachment:image-2.png)
#
# Behold the 3D radar chart, a cosmic map illustrating the Quantum Governance Index, AI-Enhanced Policy Effectiveness, Virtual Town Hall Participation, and Neural Public Sentiment Analysis across Kerala's diverse regions. Each line tells a story of a region embracing the quantum future.
#
# #### <b> Pairplot:</b>
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
#
# Dive into the intricacies of political metrics with the pairplot. Explore the relationships between Quantum Governance, AI Policy Effectiveness, Virtual Town Hall Participation, and Neural Sentiment, unraveling the interconnected tapestry of these variables.
#
# #### Correlation Heatmap:
# ![image.png](attachment:image.png)
#
# A heatmap, akin to a technicolor dream, reveals the relationships between variables. Bright hues hint at correlations, sparking contemplation on the symbiotic dance between AI-backed policies and public sentiment.
#
# ### <b>Interpretation:</b>
#
# As we decipher the visual symphony, a kaleidoscope of patterns emerges. Regions with higher Quantum Governance Index scores seem to orchestrate not just efficient governance but also policies that strike a chord with the hearts of the people.
#
# ### <b>Narrative Development:</b>
#
# Coastal Kerala emerges as the beacon of Quantum Governance, translating into progressive policies and an engaged citizenry. The correlation heatmap hints at a dance between effective AI policies and positive public sentiment, painting a picture of a Kerala that doesn't just adapt to change but orchestrates it.
#
# ### <b>Integration with Text:</b>
#
# As we traverse the visual landscapes, we see not just data points but narratives unfolding — tales of regions leading the charge, citizens actively shaping policies, and technologies seamlessly intertwining with governance.
#
# ### <b>Provide Context:</b>
#
# In the vivid tapestry of Kerala's political landscape, these metrics become markers of a transformative era. The synergy of quantum technologies and artificial intelligence becomes a compass guiding governance into uncharted territories, where decisions resonate with the hearts of the people.
#
# ### <b>Engage the Reader:</b>
#
# What role does technology play in shaping the political future of Kerala? How might citizen engagement transform with the advent of Virtual Town Halls? As we traverse these questions, we invite readers to embark on a journey of reflection, drawing parallels between the present and the quantum-infused future.
#
# ### <b>Conclusion:</b>
#
# In this imagined landscape, Quantum-Backed Political Decision-Making in Kerala for 2023 paints a promising picture. The metrics not only signify efficiency but also a harmony between policies and public sentiment, creating a political paradigm that resonates positively with the people.
#
# ### <b>Future Implications:</b>
#
# Peering beyond the horizon, the implications of these metrics extend into a future where innovation continues to shape governance. The groundwork laid in 2023 becomes a catalyst for a political landscape where technologies evolve, and citizen engagement becomes the heartbeat of democracy.
#
# ### <b>References and Citations:</b>
#
# In our journey through this speculative landscape, we draw inspiration from imagined events — the "Quantum Governance Summit 2023" and visionary leaders who navigate the intersection of technology and politics.
#
# ### <b>Disclaimer:</b>
#
# Before the curtain falls, a reminder that this dataset and these metrics are figments of imagination, meticulously crafted for the canvas of this assignment.
#
# ### <b>Proofreading and Editing:</b>
#
# The final review is a brushstroke of perfection — ensuring clarity, coherence, and a harmonious blend of words and visuals. A polished piece not only impresses but resonates.
#
# ---
#
# Feel free to modify this content further to suit your preferences and align with the specific requirements of your assignment. Good luck with your blog, and may it leave a lasting impression on your audience!
